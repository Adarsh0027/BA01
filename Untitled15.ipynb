# %% [markdown]
# <a href="https://colab.research.google.com/github/Adarsh0027/BA01/blob/main/Untitled15.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
supermarket=files.upload()
# Out:
#      <input type="file" id="files-c8e48486-2f78-4d0b-b0e0-10875b0c67af" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c8e48486-2f78-4d0b-b0e0-10875b0c67af">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
from google.colab import files
supermarket=files.upload()
print(supermarket)
# Out:
#   File "<ipython-input-8-456d469ac0be>", line 3
#     print(supermarket)
#     ^
# IndentationError: unexpected indent

# %%
from google.colab import files
teams_and_leagues=files.upload()
# Out:
#      <input type="file" id="files-79230711-9d47-481a-bffa-7622b98e828c" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-79230711-9d47-481a-bffa-7622b98e828c">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
teamgoals={"Teams":["Spain","Argentina"],"Goals":[2,8]}
df=pd.DataFrame(teamgoals)
print(df)
# Out:
#        Teams  Goals
# 0      Spain      2
# 1  Argentina      8

# %%
Nationality={"Players":["Messi","Ronaldo","Neymar"],"Country":["Argentina","Portugal","Brazil"]}
df=pd.DataFrame(Nationality)
print(df)
# Out:
#    Players    Country
# 0    Messi  Argentina
# 1  Ronaldo   Portugal
# 2   Neymar     Brazil

# %%
Marks=[10,20,30,40,50]
df=pd.DataFrame(Marks)
print(df)
# Out:
#     0
# 0  10
# 1  20
# 2  30
# 3  40
# 4  50

# %%
 df=pd.read_csv("Supermarket_sales.csv")
 print(df)
# Out:
#        No    InvoiceID Branch       City Customertype  Gender  \
# 0       1  750-67-8428      A     Yangon       Member  Female
# 1       2  226-31-3081      C  Naypyitaw       Normal  Female
# 2       3  631-41-3108      A     Yangon       Normal    Male
# 3       4  123-19-1176      A     Yangon       Member    Male
# 4       5  373-73-7910      A     Yangon       Normal    Male
# ..    ...          ...    ...        ...          ...     ...
# 995   996  233-67-5758      C  Naypyitaw       Normal    Male
# 996   997  303-96-2227      B   Mandalay       Normal  Female
# 997   998  727-02-1313      A     Yangon       Member    Male
# 998   999  347-56-2442      A     Yangon       Normal    Male
# 999  1000  849-09-3807      A     Yangon       Member  Female
#
#                 Productline  Unitprice  Quantity      Tax      Total  \
# 0         Health and beauty      74.69         7  26.1415   548.9715
# 1    Electronic accessories      15.28         5   3.8200    80.2200
# ...

# %%
print(df.head())
# Out:
#    No    InvoiceID Branch       City Customertype  Gender  \
# 0   1  750-67-8428      A     Yangon       Member  Female
# 1   2  226-31-3081      C  Naypyitaw       Normal  Female
# 2   3  631-41-3108      A     Yangon       Normal    Male
# 3   4  123-19-1176      A     Yangon       Member    Male
# 4   5  373-73-7910      A     Yangon       Normal    Male
#
#               Productline  Unitprice  Quantity      Tax     Total       Date  \
# 0       Health and beauty      74.69         7  26.1415  548.9715   1/5/2019
# 1  Electronic accessories      15.28         5   3.8200   80.2200   3/8/2019
# 2      Home and lifestyle      46.33         7  16.2155  340.5255   3/3/2019
# 3       Health and beauty      58.22         8  23.2880  489.0480  1/27/2019
# 4       Sports and travel      86.31         7  30.2085  634.3785   2/8/2019
#
#     Time      Payment    cogs  gross_margin_percentage  gross_iincome  Rating
# ...

# %%
print(df.tail())
# Out:
#        No    InvoiceID Branch       City Customertype  Gender  \
# 995   996  233-67-5758      C  Naypyitaw       Normal    Male
# 996   997  303-96-2227      B   Mandalay       Normal  Female
# 997   998  727-02-1313      A     Yangon       Member    Male
# 998   999  347-56-2442      A     Yangon       Normal    Male
# 999  1000  849-09-3807      A     Yangon       Member  Female
#
#              Productline  Unitprice  Quantity      Tax      Total       Date  \
# 995    Health and beauty      40.35         1   2.0175    42.3675  1/29/2019
# 996   Home and lifestyle      97.38        10  48.6900  1022.4900   3/2/2019
# 997   Food and beverages      31.84         1   1.5920    33.4320   2/9/2019
# 998   Home and lifestyle      65.82         1   3.2910    69.1110  2/22/2019
# 999  Fashion accessories      88.34         7  30.9190   649.2990  2/18/2019
#
#       Time  Payment    cogs  gross_margin_percentage  gross_iincome  Rating
# ...

# %%
 df=pd.read_csv("Supermarket_sales.csv")
 ct=pd.read_csv['City']
 print(ct)
# Out:
# ---------------------------------------------------------------------------
# TypeError                                 Traceback (most recent call last)
# <ipython-input-27-19820548b7ee> in <module>
#       1 df=pd.read_csv("Supermarket_sales.csv")
# ----> 2 ct=pd.read_csv['City']
#       3 print(ct)
#
# TypeError: 'function' object is not subscriptable

# %%
df['City']
# Out:
# 0         Yangon
# 1      Naypyitaw
# 2         Yangon
# 3         Yangon
# 4         Yangon
#          ...
# 995    Naypyitaw
# 996     Mandalay
# 997       Yangon
# 998       Yangon
# 999       Yangon
# Name: City, Length: 1000, dtype: object

# %%
df['Branch']
# Out:
# 0      A
# 1      C
# 2      A
# 3      A
# 4      A
#       ..
# 995    C
# 996    B
# 997    A
# 998    A
# 999    A
# Name: Branch, Length: 1000, dtype: object

# %%
df['Branch'],df['City']
# Out:
# (0      A
#  1      C
#  2      A
#  3      A
#  4      A
#        ..
#  995    C
#  996    B
#  997    A
#  998    A
#  999    A
#  Name: Branch, Length: 1000, dtype: object, 0         Yangon
#  1      Naypyitaw
#  2         Yangon
#  3         Yangon
#  4         Yangon
#           ...
#  995    Naypyitaw
#  996     Mandalay
#  997       Yangon
#  998       Yangon
#  999       Yangon
#  Name: City, Length: 1000, dtype: object)

# %%
for i in df.index:
  print(df.City[i],df.Branch[i])
# Out:
# Yangon A
# Naypyitaw C
# Yangon A
# Yangon A
# Yangon A
# Naypyitaw C
# Yangon A
# Naypyitaw C
# Yangon A
# Mandalay B
# Mandalay B
# Mandalay B
# Yangon A
# Yangon A
# Yangon A
# Mandalay B
# Yangon A
# Yangon A
# Yangon A
# Mandalay B
# Naypyitaw C
# Mandalay B
# Mandalay B
# Yangon A
# Yangon A
# Yangon A
# Mandalay B
# Yangon A
# Mandalay B
# Yangon A
# Mandalay B
# Mandalay B
# Mandalay B
# Yangon A
# Naypyitaw C
# Naypyitaw C
# Yangon A
# Yangon A
# Naypyitaw C
# Mandalay B
# Mandalay B
# Naypyitaw C
# Mandalay B
# Naypyitaw C
# Naypyitaw C
# Mandalay B
# Mandalay B
# Mandalay B
# Mandalay B
# Naypyitaw C
# Naypyitaw C
# Yangon A
# Mandalay B
# Naypyitaw C
# Mandalay B
# Naypyitaw C
# Yangon A
# Yangon A
# Yangon A
# Naypyitaw C
# Naypyitaw C
# Naypyitaw C
# Mandalay B
# Yangon A
# Mandalay B
# Yangon A
# Naypyitaw C
# Mandalay B
# Yangon A
# Yangon A
# Naypyitaw C
# Naypyitaw C
# Mandalay B
# Naypyitaw C
# Yangon A
# Naypyitaw C
# Naypyitaw C
# Yangon A
# Naypyitaw C
# ...

# %%
from google.colab import files
players=files.upload()
# Out:
#      <input type="file" id="files-66b14679-ebbf-4fca-a89a-34d315587f83" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-66b14679-ebbf-4fca-a89a-34d315587f83">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df=pd.read_csv("players_20.csv")

# %%
print(df.short_name.head(1))
df.overall.max()
# Out:
# 0    L. Messi
# Name: short_name, dtype: object
# 94

# %%
df.age.min()
# Out:
# 16

# %%
df.age.max()
# Out:
# 42

# %%
df.overall.idxmax()
# Out:
# 0

# %%
print(df.long_name," has the highest overall of",df.overall.max)
# Out:
# 0             Lionel Andrés Messi Cuccittini
# 1        Cristiano Ronaldo dos Santos Aveiro
# 2              Neymar da Silva Santos Junior
# 3                                  Jan Oblak
# 4                                Eden Hazard
#                         ...
# 18273                                     邵帅
# 18274                           Mingjie Xiao
# 18275                                     张威
# 18276                                    汪海健
# 18277                                    潘喜明
# Name: long_name, Length: 18278, dtype: object  has the highest overall of <bound method NDFrame._add_numeric_operations.<locals>.max of 0        94
# 1        93
# 2        92
# 3        91
# 4        91
#          ..
# 18273    48
# 18274    48
# 18275    48
# 18276    48
# 18277    48
# Name: overall, Length: 18278, dtype: int64>

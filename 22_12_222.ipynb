# %% [markdown]
# <a href="https://colab.research.google.com/github/Adarsh0027/BA01/blob/main/22_12_222.ipynb" target="_parent"><img src="https://colab.research.google.com/assets/colab-badge.svg" alt="Open In Colab"/></a>

# %%
from google.colab import files
marks=files.upload()
# Out:
#      <input type="file" id="files-c3d8a2c9-5760-4875-91c4-a173ca824217" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c3d8a2c9-5760-4875-91c4-a173ca824217">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
import pandas as pd
import  plotly.express as plt
import matplotlib.pyplot as py 
df=pd.read_csv("Student Marks vs Days Present (1) (1).csv")
m=df["Marks In Percentage"]
n=df["Days Present"]
py.scatter(m,n,color='blue')

# %%
#the student with most attendance has scored the highest marks and the student with least attendance has scored the least percentage in marks 
#Considering the min percentage of marks as 50 each student has to atend atleast of 14 classes

# %%
from google.colab import files
pm=files.upload()
# Out:
#      <input type="file" id="files-e3749474-70a4-4808-b7c8-f6d0d8c432eb" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-e3749474-70a4-4808-b7c8-f6d0d8c432eb">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df=pd.read_csv("pixelmath.csv")
print(df.groupby("level")["attempt"].mean())
fig=plt.bar(df,x=["Level1","Level2","Level3","Level4"],y=df.groupby("level")["attempt"].mean())
fig.show()
# Out:
# level
# Level 1    0.751445
# Level 2    0.863281
# Level 3    0.698113
# Level 4    0.734694
# Name: attempt, dtype: float64
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %%
from google.colab import files
pm=files.upload()
# Out:
#      <input type="file" id="files-c3740578-a2e0-4a35-98eb-8057cbd15828" name="files[]" multiple disabled
#         style="border:none" />
#      <output id="result-c3740578-a2e0-4a35-98eb-8057cbd15828">
#       Upload widget is only available when the cell has been executed in the
#       current browser session. Please rerun this cell to enable.
#       </output>
#       <script>// Copyright 2017 Google LLC
# //
# // Licensed under the Apache License, Version 2.0 (the "License");
# // you may not use this file except in compliance with the License.
# // You may obtain a copy of the License at
# //
# //      http://www.apache.org/licenses/LICENSE-2.0
# //
# // Unless required by applicable law or agreed to in writing, software
# // distributed under the License is distributed on an "AS IS" BASIS,
# // WITHOUT WARRANTIES OR CONDITIONS OF ANY KIND, either express or implied.
# // See the License for the specific language governing permissions and
# // limitations under the License.
#
# ...

# %%
df=pd.read_csv("cups of coffee vs hours of sleep.csv")
print(df.groupby("Coffee in ml")["sleep in hours"].mean())
fig=plt.bar(df,x=["1","2","3","4","5","6"],y=df.groupby("Coffee in ml")["sleep in hours"].mean())
fig.show()
# Out:
# Coffee in ml
# 20    89.0
# 30    75.0
# 45    65.0
# 50    40.0
# 60    20.0
# 80    10.0
# Name: sleep in hours, dtype: float64
# <html>
# <head><meta charset="utf-8" /></head>
# <body>
#     <div>            <script src="https://cdnjs.cloudflare.com/ajax/libs/mathjax/2.7.5/MathJax.js?config=TeX-AMS-MML_SVG"></script><script type="text/javascript">if (window.MathJax) {MathJax.Hub.Config({SVG: {font: "STIX-Web"}});}</script>                <script type="text/javascript">window.PlotlyConfig = {MathJaxConfig: 'local'};</script>
# ...

# %% [markdown]
# #coffee is good for employees who intend to work in late night shifts
# #it is also harmfull if you drink coffee daily and have less hours of sleep the
# #at least of 4ml coffee per week is required for a person to get reduced to sleep
